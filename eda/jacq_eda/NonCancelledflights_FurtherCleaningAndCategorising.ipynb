# %%
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import re
import matplotlib.pyplot as plt # plotting
import numpy as np # linear algebra
import os # accessing directory structure
import csv
import math
import seaborn as sns

# %% [markdown]
# ## Categorising data
#
# <br>1. Making carrier df
# <br>2. Making airport df
# <br>3. Combining all df

# %%
df = pd.read_csv("flights_without_cancellation_data2.csv")

# %%
carrier_df = pd.read_csv("data/different_carriers.csv")

# %%
airport_df = pd.read_csv("data/airports_in_respective_states.csv")

# %%
airport_df.head()
# Out:
#   airport          airport_name         city state
# 0     YAK       Yakutat Airport      Yakutat    AK
# 1     GST      Gustavus Airport     Gustavus    AK
# 2     AKN   King Salmon Airport  King Salmon    AK
# 3     DLG    Dillingham Airport   Dillingham    AK
# 4     WRG      Wrangell Airport     Wrangell    AK

# %%
df.drop(columns=['Cancelled', 'CancellationCode', 'DayOfWeek'], inplace = True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9674807 entries, 0 to 9674806
# Data columns (total 24 columns):
#  #   Column             Dtype
# ---  ------             -----
#  0   ActualElapsedTime  float64
#  1   AirTime            float64
#  2   ArrDelay           float64
#  3   ArrTime            float64
#  4   CRSArrTime         int64
#  5   CRSDepTime         int64
#  6   CRSElapsedTime     float64
#  7   CarrierDelay       float64
#  8   DepDelay           float64
#  9   DepTime            float64
#  10  Dest               object
#  11  Distance           float64
#  12  Diverted           int64
#  13  FlightNum          int64
#  14  LateAircraftDelay  float64
#  15  NASDelay           float64
#  16  Origin             object
#  17  SecurityDelay      float64
#  18  TailNum            object
#  19  TaxiIn             float64
#  20  TaxiOut            float64
#  21  UniqueCarrier      object
#  22  WeatherDelay       float64
#  23  Date               object
# dtypes: float64(15), int64(4), object(5)
# memory usage: 1.7+ GB

# %%
# Merge DataFrame A with DataFrame B for origin airport and rearrange columns
merged_on_origin = pd.merge(df, airport_df, left_on='Origin', right_on='airport', how='left')
merged_on_origin.drop(columns=['airport', 'city'], inplace = True)
merged_on_origin.rename(columns={'airport_name': 'OriginAirportName', 'state': 'OriginState'}, inplace=True)

# %%
# Check columns
merged_on_origin.columns.tolist()
# Out:
# ['ActualElapsedTime',
#  'AirTime',
#  'ArrDelay',
#  'ArrTime',
#  'CRSArrTime',
#  'CRSDepTime',
#  'CRSElapsedTime',
#  'CarrierDelay',
#  'DepDelay',
#  'DepTime',
#  'Dest',
#  'Distance',
#  'Diverted',
#  'FlightNum',
#  'LateAircraftDelay',
#  'NASDelay',
#  'Origin',
#  'SecurityDelay',
#  'TailNum',
#  'TaxiIn',
#  'TaxiOut',
#  'UniqueCarrier',
#  'WeatherDelay',
#  'Date',
#  'OriginAirportName',
#  'OriginState']

# %%
# Merge DataFrame A with DataFrame B for destination airport and rearrange columns
merged_on_dest = pd.merge(merged_on_origin, airport_df, left_on='Dest', right_on='airport', how='left')
merged_on_dest.drop(columns=['airport', 'city'], inplace = True)
merged_on_dest.rename(columns={'airport_name': 'DestAirportName', 'state': 'DestState'}, inplace=True)

# %%
# Check columns
merged_on_dest.columns.tolist()
# Out:
# ['ActualElapsedTime',
#  'AirTime',
#  'ArrDelay',
#  'ArrTime',
#  'CRSArrTime',
#  'CRSDepTime',
#  'CRSElapsedTime',
#  'CarrierDelay',
#  'DepDelay',
#  'DepTime',
#  'Dest',
#  'Distance',
#  'Diverted',
#  'FlightNum',
#  'LateAircraftDelay',
#  'NASDelay',
#  'Origin',
#  'SecurityDelay',
#  'TailNum',
#  'TaxiIn',
#  'TaxiOut',
#  'UniqueCarrier',
#  'WeatherDelay',
#  'Date',
#  'OriginAirportName',
#  'OriginState',
#  'DestAirportName',
#  'DestState']

# %%
desired_order = ['ActualElapsedTime',
 'AirTime',
 'ArrDelay',
 'DepDelay',
 'ArrTime',
 'DepTime',
 'CRSArrTime',
 'CRSDepTime',
 'CRSElapsedTime',
 'CarrierDelay',
 'DepDelay',
 'LateAircraftDelay',
 'SecurityDelay',
 'WeatherDelay',
 'NASDelay',
 'Distance',
 'Diverted',
 'Origin',
 'OriginAirportName',
 'OriginState',
 'Dest',
 'DestAirportName',
 'DestState',
 'TaxiIn',
 'TaxiOut',
 'TailNum',
 'UniqueCarrier',
 'FlightNum',
 'Date',
]

merged_on_dest = merged_on_dest[desired_order]

# %%
merged_on_dest
# Out:
#          ActualElapsedTime  AirTime  ArrDelay  DepDelay  ArrTime  DepTime  \
# 0                     19.0      NaN      -2.0       0.0   1404.0   1345.0
# 1                     49.0      NaN      -6.0       0.0   1359.0   1310.0
# 2                     26.0      NaN       2.0       0.0   1536.0   1510.0
# 3                     31.0      NaN      -2.0      -3.0   1253.0   1222.0
# 4                    161.0      NaN      19.0       0.0   1051.0    910.0
# ...                    ...      ...       ...       ...      ...      ...
# 9674802               87.0     63.0      -5.0      -8.0    749.0    622.0
# 9674803               87.0     47.0      48.0      34.0   2011.0   1844.0
# 9674804              141.0    116.0     -18.0      -1.0   1022.0    701.0
# 9674805              189.0    173.0     -12.0       4.0   1508.0   1059.0
# 9674806              127.0    109.0       4.0      17.0   2104.0   1757.0
#
#          CRSArrTime  CRSDepTime  CRSElapsedTime  CarrierDelay  ...  \
# 0              1406        1345            21.0           NaN  ...
# 1              1405        1310            55.0           NaN  ...
# 2              1534        1510            24.0           NaN  ...
# 3              1255        1225            30.0           NaN  ...
# 4              1032         910           142.0           NaN  ...
# ...             ...         ...             ...           ...  ...
# 9674802         754         630            84.0           NaN  ...
# 9674803        1923        1810            73.0           0.0  ...
# 9674804        1040         702           158.0           NaN  ...
# 9674805        1520        1055           205.0           NaN  ...
# 9674806        2100        1740           140.0           NaN  ...
#
#          OriginState  Dest                                    DestAirportName  \
# 0                 MT   BZN                  Bozeman Yellowstone International
# 1                 PA   ABE                        Lehigh Valley International
# 2                 KY   SDF              Louisville Muhammad Ali International
# 3                 NY   SYR                     Syracuse Hancock International
# 4                 NY   STL                     St Louis Lambert International
# ...              ...   ...                                                ...
# 9674802           PA   CLE                    Cleveland-Hopkins International
# 9674803           NY   BWI   Baltimore/Washington International Thurgood M...
# 9674804           WA   DEN                               Denver International
# 9674805           AZ   MDW                       Chicago Midway International
# 9674806           CO   MDW                       Chicago Midway International
#
#          DestState  TaxiIn  TaxiOut  TailNum UniqueCarrier FlightNum  \
# 0               MT     NaN      NaN      NaN            DL      1807
# 1               PA     NaN      NaN      NaN            US       312
# 2               KY     NaN      NaN      NaN            DL      1060
# 3               NY     NaN      NaN      NaN            PI       874
# 4               MO     NaN      NaN      NaN            TW       245
# ...            ...     ...      ...      ...           ...       ...
# 9674802         OH    15.0      9.0   N13123            XE      2651
# 9674803         MD     7.0     33.0   N952AT            FL       402
# 9674804         CO    10.0     15.0   N597UA            UA       386
# 9674805         IL     5.0     11.0   N476WN            WN       733
# 9674806         IL     7.0     11.0   N373SW            WN      1227
#
#                Date
# 0        01/01/1988
# 1        01/01/1988
# 2        01/01/1988
# 3        01/01/1988
# 4        01/01/1988
# ...             ...
# 9674802  31/12/2008
# 9674803  31/12/2008
# 9674804  31/12/2008
# 9674805  31/12/2008
# 9674806  31/12/2008
#
# [9674807 rows x 29 columns]

# %%
# Merge on carrier names
merged_on_carrier = pd.merge(merged_on_dest, carrier_df, left_on='UniqueCarrier', right_on='carrier', how='left')
merged_on_carrier.drop(columns=['carrier'], inplace = True)
merged_on_carrier.rename(columns={'carrier_name': 'CarrierName'}, inplace=True)

# %%
# Check columns
merged_on_carrier.columns.tolist()
# Out:
# ['ActualElapsedTime',
#  'AirTime',
#  'ArrDelay',
#  'DepDelay',
#  'ArrTime',
#  'DepTime',
#  'CRSArrTime',
#  'CRSDepTime',
#  'CRSElapsedTime',
#  'CarrierDelay',
#  'DepDelay',
#  'LateAircraftDelay',
#  'SecurityDelay',
#  'WeatherDelay',
#  'NASDelay',
#  'Distance',
#  'Diverted',
#  'Origin',
#  'OriginAirportName',
#  'OriginState',
#  'Dest',
#  'DestAirportName',
#  'DestState',
#  'TaxiIn',
#  'TaxiOut',
#  'TailNum',
#  'UniqueCarrier',
#  'FlightNum',
#  'Date',
#  'CarrierName']

# %%
desired_order = ['ActualElapsedTime',
 'AirTime',
 'ArrDelay',
 'DepDelay',
 'ArrTime',
 'DepTime',
 'CRSArrTime',
 'CRSDepTime',
 'CRSElapsedTime',
 'CarrierDelay',
 'DepDelay',
 'LateAircraftDelay',
 'SecurityDelay',
 'WeatherDelay',
 'NASDelay',
 'Distance',
 'Diverted',
 'Origin',
 'OriginAirportName',
 'OriginState',
 'Dest',
 'DestAirportName',
 'DestState',
 'TaxiIn',
 'TaxiOut',
 'TailNum',
 'UniqueCarrier',
 'CarrierName',
 'FlightNum',
 'Date',
]

merged_on_carrier = merged_on_carrier[desired_order]
merged_on_carrier
# Out:
#          ActualElapsedTime  AirTime  ArrDelay  DepDelay  DepDelay  DepDelay  \
# 0                     19.0      NaN      -2.0       0.0       0.0       0.0
# 1                     49.0      NaN      -6.0       0.0       0.0       0.0
# 2                     26.0      NaN       2.0       0.0       0.0       0.0
# 3                     31.0      NaN      -2.0      -3.0      -3.0      -3.0
# 4                    161.0      NaN      19.0       0.0       0.0       0.0
# ...                    ...      ...       ...       ...       ...       ...
# 9674802               87.0     63.0      -5.0      -8.0      -8.0      -8.0
# 9674803               87.0     47.0      48.0      34.0      34.0      34.0
# 9674804              141.0    116.0     -18.0      -1.0      -1.0      -1.0
# 9674805              189.0    173.0     -12.0       4.0       4.0       4.0
# 9674806              127.0    109.0       4.0      17.0      17.0      17.0
#
#          DepDelay  ArrTime  DepTime  CRSArrTime  ...  Dest  \
# 0             0.0   1404.0   1345.0        1406  ...   BZN
# 1             0.0   1359.0   1310.0        1405  ...   ABE
# 2             0.0   1536.0   1510.0        1534  ...   SDF
# 3            -3.0   1253.0   1222.0        1255  ...   SYR
# 4             0.0   1051.0    910.0        1032  ...   STL
# ...           ...      ...      ...         ...  ...   ...
# 9674802      -8.0    749.0    622.0         754  ...   CLE
# 9674803      34.0   2011.0   1844.0        1923  ...   BWI
# 9674804      -1.0   1022.0    701.0        1040  ...   DEN
# 9674805       4.0   1508.0   1059.0        1520  ...   MDW
# 9674806      17.0   2104.0   1757.0        2100  ...   MDW
#
#                                            DestAirportName  DestState  TaxiIn  \
# 0                        Bozeman Yellowstone International         MT     NaN
# 1                              Lehigh Valley International         PA     NaN
# 2                    Louisville Muhammad Ali International         KY     NaN
# 3                           Syracuse Hancock International         NY     NaN
# 4                           St Louis Lambert International         MO     NaN
# ...                                                    ...        ...     ...
# 9674802                    Cleveland-Hopkins International         OH    15.0
# 9674803   Baltimore/Washington International Thurgood M...         MD     7.0
# 9674804                               Denver International         CO    10.0
# 9674805                       Chicago Midway International         IL     5.0
# 9674806                       Chicago Midway International         IL     7.0
#
#          TaxiOut  TailNum  UniqueCarrier                  CarrierName  \
# 0            NaN      NaN             DL         Delta Air Lines Inc.
# 1            NaN      NaN             US              US Airways Inc.
# 2            NaN      NaN             DL         Delta Air Lines Inc.
# 3            NaN      NaN             PI                          NaN
# 4            NaN      NaN             TW                          NaN
# ...          ...      ...            ...                          ...
# 9674802      9.0   N13123             XE                          NaN
# 9674803     33.0   N952AT             FL  AirTran Airways Corporation
# 9674804     15.0   N597UA             UA        United Air Lines Inc.
# 9674805     11.0   N476WN             WN       Southwest Airlines Co.
# 9674806     11.0   N373SW             WN       Southwest Airlines Co.
#
#          FlightNum        Date
# 0             1807  01/01/1988
# 1              312  01/01/1988
# 2             1060  01/01/1988
# 3              874  01/01/1988
# 4              245  01/01/1988
# ...            ...         ...
# 9674802       2651  31/12/2008
# 9674803        402  31/12/2008
# 9674804        386  31/12/2008
# 9674805        733  31/12/2008
# 9674806       1227  31/12/2008
#
# [9674807 rows x 36 columns]

# %%
merged_on_carrier.to_csv("data/categorised_NONcancelled_flights_incomplete.csv", index=False)
merged_on_carrier.shape
# Out:
# (9674807, 36)

# %%
merged_on_carrier.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9674807 entries, 0 to 9674806
# Data columns (total 36 columns):
#  #   Column             Dtype
# ---  ------             -----
#  0   ActualElapsedTime  float64
#  1   AirTime            float64
#  2   ArrDelay           float64
#  3   DepDelay           float64
#  4   DepDelay           float64
#  5   DepDelay           float64
#  6   DepDelay           float64
#  7   ArrTime            float64
#  8   DepTime            float64
#  9   CRSArrTime         int64
#  10  CRSDepTime         int64
#  11  CRSElapsedTime     float64
#  12  CarrierDelay       float64
#  13  DepDelay           float64
#  14  DepDelay           float64
#  15  DepDelay           float64
#  16  DepDelay           float64
#  17  LateAircraftDelay  float64
#  18  SecurityDelay      float64
#  19  WeatherDelay       float64
#  20  NASDelay           float64
#  21  Distance           float64
#  22  Diverted           int64
#  23  Origin             object
#  24  OriginAirportName  object
#  25  OriginState        object
#  26  Dest               object
#  27  DestAirportName    object
#  28  DestState          object
#  29  TaxiIn             float64
#  30  TaxiOut            float64
#  31  TailNum            object
#  32  UniqueCarrier      object
#  33  CarrierName        object
#  34  FlightNum          int64
#  35  Date               object
# dtypes: float64(22), int64(4), object(10)
# memory usage: 2.7+ GB
